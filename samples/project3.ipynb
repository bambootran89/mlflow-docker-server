# %%
import random
from functools import partial
from itertools import starmap

from more_itertools import consume

import mlflow
# Out:
# /home/jovyan/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.0' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/jovyan/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
#!pip install more_itertools

# %% [markdown]
# # Leveraging Child Runs in MLflow for Hyperparameter Tuning
# In the world of machine learning, the task of hyperparameter tuning is central to model optimization. This process involves performing multiple runs with varying parameters to identify the most effective combination, ultimately enhancing model performance. However, this can lead to a large volume of runs, making it challenging to track, organize, and compare these experiments effectively.
#
# MLflow incorporates the ability to simplify the large-data-volume issue by offering a structured approach to manage this complexity. In this notebook, we will explore the concept of Parent and Child Runs in MLflow, a feature that provides a hierarchical structure to organize runs. This hierarchy allows us to bundle a set of runs under a parent run, making it much more manageable and intuitive to analyze and compare the results of different hyperparameter combinations. This structure proves to be especially beneficial in understanding and visualizing the outcomes of hyperparameter tuning processes.
#
# Throughout this notebook, we will: - Understand the usage and benefits of parent and child runs in MLflow. - Walk through a practical example demonstrating the organization of runs without and with child runs. - Observe how child runs aid in effectively tracking and comparing the results of different parameter combinations. - Demonstrate a further refinement by having the parent run maintain the state of the best conditions from child run iterations.

# %% [markdown]
# # Starting Without Child Runs
# Before diving into the structured world of parent and child runs, let’s begin by observing the scenario without utilizing child runs in MLflow. In this section, we perform multiple runs with different parameters and metrics without associating them as child runs of a parent run.
#
# Below is the code executing five hyperparameter tuning runs. These runs are not organized as child runs, and hence, each run is treated as an independent entity in MLflow. We will observe the challenges this approach poses in tracking and comparing runs, setting the stage for the introduction of child runs in the subsequent sections.
#
# After running the above code, you can proceed to the MLflow UI to view the logged runs. Observing the organization (or lack thereof) of these runs will help in appreciating the structured approach offered by using child runs, which we will explore in the next sections of this notebook.

# %%
import os
os.environ['MLFLOW_TRACKING_USERNAME'] = "lam"
os.environ['MLFLOW_TRACKING_PASSWORD'] = "ds@lam1"

# %%
# Set the tracking uri and experiment
mlflow.set_tracking_uri("http://localhost:5005")
mlflow.set_experiment("No Child Runs")
# Out:
# <Experiment: artifact_location='s3://mlflow-artifacts/mlflow/7', creation_time=1723453173213, experiment_id='7', last_update_time=1723453173213, lifecycle_stage='active', name='No Child Runs', tags={}>

# %%
# Define a function to log parameters and metrics
def log_run(run_name, test_no):
    with mlflow.start_run(run_name=run_name):
        mlflow.log_param("param1", random.choice(["a", "b", "c"]))
        mlflow.log_param("param2", random.choice(["d", "e", "f"]))
        mlflow.log_metric("metric1", random.uniform(0, 1))
        mlflow.log_metric("metric2", abs(random.gauss(5, 2.5)))


# Generate run names
def generate_run_names(test_no, num_runs=5):
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function
def execute_tuning(test_no):
    # Partial application of the log_run function
    log_current_run = partial(log_run, test_no=test_no)
    # Generate run names and apply log_current_run function to each run name
    runs = starmap(log_current_run, ((run_name,) for run_name in generate_run_names(test_no)))
    # Consume the iterator to execute the runs
    consume(runs)



# Execute 5 hyperparameter tuning runs
consume(starmap(execute_tuning, ((x,) for x in range(5))))
# Out:
# 2024/08/12 15:59:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run run
INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/7/runs/d801b46f5c80428ca76b6d748ac95dc1.
# 2024/08/12 16:00:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/7/runs/cc5c91add9134770a37dfd3809b41f40.
# 2024/08/12 16:00:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/7/runs/565e0d3a47614239ac69a929d4a7a939.
# 2024/08/12 16:00:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/7/runs/93ea9725e4874d6d8575bdc5d22a19ad.
# 2024/08/12 16:00:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.

# %% [markdown]
# # Iterative development simulation
# It is very rare that a tuning run will be conducted in isolation. Typically, we will run many iterations of combinations of parameters, refining our search space to achieve the best possible potential results in the shortest amount of execution time.
#
# In order to arrive at this limited set of selection parameters ranges and conditions, we will be executing many such tests.

# %%
# What if we need to run this again?
consume(starmap(execute_tuning, ((x,) for x in range(5))))
# Out:
# 2024/08/12 16:00:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_0 at: http://localhost:5005/#/experiments/7/runs/451a198642c845f78e66f8a0b17981c1.
# 2024/08/12 16:00:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_0 at: http://localhost:5005/#/experiments/7/runs/a9d2e06eddd34bce9cda03f96b7787f1.
# 2024/08/12 16:00:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_0 at: http://localhost:5005/#/experiments/7/runs/dd308c5ec5b84340b3ee606c7adf0d28.
# 2024/08/12 16:00:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_0 at: http://localhost:5005/#/experiments/7/runs/f04ceb1dfe044576911a8196091d1fef.
# 2024/08/12 16:00:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_0 at: http://localhost:5005/#/experiments/7/runs/6f7365ef34e844738c3bd439fd49ff87.
# 2024/08/12 16:00:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_1 at: http://localhost:5005/#/experiments/7/runs/0edce4414d664ebd9d7f3573b6ff23bf.
# 2024/08/12 16:00:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_1 at: http://localhost:5005/#/experiments/7/runs/60053a83376d4a738f92866822fd1d68.
# 2024/08/12 16:00:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_1 at: http://localhost:5005/#/experiments/7/runs/07f29ba1847240598234baafb76d1b60.
# 2024/08/12 16:00:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_1 at: http://localhost:5005/#/experiments/7/runs/39bda43f8be64412a2cec543db1fc549.
# 2024/08/12 16:00:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_1 at: http://localhost:5005/#/experiments/7/runs/6e5dfeac333f4c9aa5865a5eb1cc6e7f.
# 2024/08/12 16:00:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_2 at: http://localhost:5005/#/experiments/7/runs/c929ea845ee342c3890ac1d6c23550a0.
# 2024/08/12 16:00:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_2 at: http://localhost:5005/#/experiments/7/runs/acdbd4688cdc41e39929dedabfc9caa9.
# 2024/08/12 16:00:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_2 at: http://localhost:5005/#/experiments/7/runs/aabf1774e96142639831d14775cbec58.
# 2024/08/12 16:00:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_2 at: http://localhost:5005/#/experiments/7/runs/7d47865a753f488daabb4b91f329bc42.
# 2024/08/12 16:00:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_2 at: http://localhost:5005/#/experiments/7/runs/4f59f00a90554f6385aa63ac617edab4.
# 2024/08/12 16:00:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_3 at: http://localhost:5005/#/experiments/7/runs/fe8312c299254a23af0b3caafe6ca21e.
# 2024/08/12 16:00:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_3 at: http://localhost:5005/#/experiments/7/runs/4f7e64d1eaac4ff7812b4f6e6237558e.
# 2024/08/12 16:00:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_3 at: http://localhost:5005/#/experiments/7/runs/1f38a1a1132c4591b8ac4295da0c8ea0.
# 2024/08/12 16:00:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_3 at: http://localhost:5005/#/experiments/7/runs/ee6302da4a7b451a91893193c6b06c28.
# 2024/08/12 16:00:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_3 at: http://localhost:5005/#/experiments/7/runs/f46030ff9f8d499ba6ff8254ecddcf16.
# 2024/08/12 16:00:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_4 at: http://localhost:5005/#/experiments/7/runs/92708bc2b6d14889a22db2dd3478e4cf.
# 2024/08/12 16:00:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/7/runs/0c4534b75d3643009614d2b54cfdc603.
# 2024/08/12 16:00:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/7/runs/2a3d485f64c949c49bbcaffcb7b991e7.
# 2024/08/12 16:00:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/7/runs/0e124464e0ab4c1fa16684077d00e37d.
# 2024/08/12 16:00:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.
# 2024/08/12 16:00:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/7/runs/7f10f92f122d4f7783955d50a6303089.
# 2024/08/12 16:00:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/7.

# %% [markdown]
# # Using Child Runs for Improved Organization
# As we proceed, the spotlight now shifts to the utilization of Child Runs in MLflow. This feature brings forth an organized structure, inherently solving the challenges we observed in the previous section. The child runs are neatly nested under a parent run, providing a clear, hierarchical view of all the runs, making it exceptionally convenient to analyze and compare the outcomes.
#
# # Benefits of Using Child Runs:
# Structured View: The child runs, grouped under a parent run, offer a clean and structured view in the MLflow UI.
#
# Efficient Filtering: The hierarchical organization facilitates efficient filtering and selection, enhancing the usability of the MLflow UI and search APIs.
#
# Distinct Naming: Utilizing visually distinct naming for runs aids in effortless identification and selection within the UI.
#
# In this section, the code is enhanced to use child runs. Each execute_tuning function call creates a parent run, under which multiple child runs are nested. These child runs are performed with different parameters and metrics. Additionally, we incorporate tags to further enhance the search and filter capabilities in MLflow.
#
# Notice the inclusion of the nested=True parameter in the mlflow.start_run() function, indicating the creation of a child run. The addition of tags, using the mlflow.set_tag() function, provides an extra layer of information, useful for filtering and searching runs effectively.
#
# Let’s dive into the code and observe the seamless organization and enhanced functionality brought about by the use of child runs in MLflow.

# %%
# Define a function to log parameters and metrics and add tag
# logging for search_runs functionality
def log_run(run_name, test_no, param1_choices, param2_choices, tag_ident):
    with mlflow.start_run(run_name=run_name, nested=True):
        mlflow.log_param("param1", random.choice(param1_choices))
        mlflow.log_param("param2", random.choice(param2_choices))
        mlflow.log_metric("metric1", random.uniform(0, 1))
        mlflow.log_metric("metric2", abs(random.gauss(5, 2.5)))
        mlflow.set_tag("test_identifier", tag_ident)


# Generate run names
def generate_run_names(test_no, num_runs=5):
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function, allowing for param overrides,
# run_name disambiguation, and tagging support
def execute_tuning(
    test_no, param1_choices=("a", "b", "c"), param2_choices=("d", "e", "f"), test_identifier=""
):
    ident = "default" if not test_identifier else test_identifier
    # Use a parent run to encapsulate the child runs
    with mlflow.start_run(run_name=f"parent_run_test_{ident}_{test_no}"):
        # Partial application of the log_run function
        log_current_run = partial(
            log_run,
            test_no=test_no,
            param1_choices=param1_choices,
            param2_choices=param2_choices,
            tag_ident=ident,
        )
        mlflow.set_tag("test_identifier", ident)
        # Generate run names and apply log_current_run function to each run name
        runs = starmap(log_current_run, ((run_name,) for run_name in generate_run_names(test_no)))
        # Consume the iterator to execute the runs
        consume(runs)


# Set the tracking uri and experiment
mlflow.set_tracking_uri("http://localhost:5005")
mlflow.set_experiment("Nested Child Association")

# Define custom parameters
param_1_values = ["x", "y", "z"]
param_2_values = ["u", "v", "w"]

# Execute hyperparameter tuning runs with custom parameter choices
consume(starmap(execute_tuning, ((x, param_1_values, param_2_values) for x in range(5))))
# Out:
# 2024/08/12 16:00:55 INFO mlflow.tracking.fluent: Experiment with name 'Nested Child Association' does not exist. Creating a new experiment.
# 2024/08/12 16:00:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_0 at: http://localhost:5005/#/experiments/8/runs/9ad2bf1b72c0402fa95ccce26f27b866.
# 2024/08/12 16:00:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:00:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_0 at: http://localhost:5005/#/experiments/8/runs/7fec5d8299c447aaae8a09cf8e208f4a.
# 2024/08/12 16:00:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_0 at: http://localhost:5005/#/experiments/8/runs/a774bf2266414a7c9650d975f2d942f6.
# 2024/08/12 16:01:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_0 at: http://localhost:5005/#/experiments/8/runs/ea99b07374e94a118450079b6b2c450e.
# 2024/08/12 16:01:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_0 at: http://localhost:5005/#/experiments/8/runs/a79ec761ca0b43f180117f08f8e963e5.
# 2024/08/12 16:01:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_default_0 at: http://localhost:5005/#/experiments/8/runs/7ade426636ce49048947ea255441da03.
# 2024/08/12 16:01:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_1 at: http://localhost:5005/#/experiments/8/runs/bd9d2e04396a479fb25c52343dfdda9f.
# 2024/08/12 16:01:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_1 at: http://localhost:5005/#/experiments/8/runs/dbcce95c24654ccaae0ded29f5ba73ea.
# 2024/08/12 16:01:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_1 at: http://localhost:5005/#/experiments/8/runs/858020f3c9d5408dbb3f8c6bd959ab6a.
# 2024/08/12 16:01:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_1 at: http://localhost:5005/#/experiments/8/runs/fd1cf9307cb2481ebf9f1bdef40243f5.
# 2024/08/12 16:01:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_1 at: http://localhost:5005/#/experiments/8/runs/5732bbf123e24ab18ccbd31cf172b50b.
# 2024/08/12 16:01:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_default_1 at: http://localhost:5005/#/experiments/8/runs/d1b780fdc035409abe820d30680bbf95.
# 2024/08/12 16:01:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_2 at: http://localhost:5005/#/experiments/8/runs/df10221624e64f30ae2e5fa7d5ef9b13.
# 2024/08/12 16:01:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_2 at: http://localhost:5005/#/experiments/8/runs/c382fcc961354b6d9fe0b9e55e7ed687.
# 2024/08/12 16:01:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_2 at: http://localhost:5005/#/experiments/8/runs/dd0e519162ea4d10af707499c12a8f2a.
# 2024/08/12 16:01:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_2 at: http://localhost:5005/#/experiments/8/runs/abfb9be6e2564fef81b33684f247973e.
# 2024/08/12 16:01:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_2 at: http://localhost:5005/#/experiments/8/runs/bc7541c3f571443091e280986b6d0e36.
# 2024/08/12 16:01:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_default_2 at: http://localhost:5005/#/experiments/8/runs/e32edd7511f74b2cbcb47fdd47d11f56.
# 2024/08/12 16:01:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_3 at: http://localhost:5005/#/experiments/8/runs/ea08ac6415104787bc4b0b3d1f5521de.
# 2024/08/12 16:01:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_3 at: http://localhost:5005/#/experiments/8/runs/a59264f6224748df98f4f61159430b20.
# 2024/08/12 16:01:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_3 at: http://localhost:5005/#/experiments/8/runs/715a9e47215045b388552db70e916f3b.
# 2024/08/12 16:01:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_3 at: http://localhost:5005/#/experiments/8/runs/6b85e2f42cb04b5eb44aa91f88d5c8b6.
# 2024/08/12 16:01:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_3 at: http://localhost:5005/#/experiments/8/runs/eadd58419b4146fcb07eca333eca25ca.
# 2024/08/12 16:01:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_default_3 at: http://localhost:5005/#/experiments/8/runs/99cb4e97aace4029ae9b40d6267cbb81.
# 2024/08/12 16:01:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_4 at: http://localhost:5005/#/experiments/8/runs/de8948904d95449ab1a926fd3f253d0b.
# 2024/08/12 16:01:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/8/runs/7aa112425fb5445fb283f1a78f4d385f.
# 2024/08/12 16:01:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/8/runs/09a68046d46f4951b217c814b322d9e6.
# 2024/08/12 16:01:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/8/runs/2fd3e02a9b56446a96d944e782b60ff3.
# 2024/08/12 16:01:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/8/runs/ac6f2654f42542c88a1097df64367e45.
# 2024/08/12 16:01:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_default_4 at: http://localhost:5005/#/experiments/8/runs/d0bde6ff9bd94a128f418e3819b4cff8.
# 2024/08/12 16:01:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.

# %% [markdown]
# # Tailoring the Hyperparameter Tuning Process
# In this segment, we are taking a step further in our iterative process of hyperparameter tuning. Observe the execution of additional hyperparameter tuning runs, where we introduce custom parameter choices and a unique identifier for tagging.
#
# # What Are We Doing?
# Custom Parameter Choices: We are now employing different parameter values (param_1_values as ["x", "y", "z"] and param_2_values as ["u", "v", "w"]) for the runs.
#
# Unique Identifier for Tagging: A distinct identifier (ident) is used for tagging, which provides an easy and efficient way to filter and search these specific runs in the MLflow UI.
#
# # How Does It Apply to Hyperparameter Tuning?
# Parameter Sensitivity Analysis: This step allows us to analyze the sensitivity of the model to different parameter values, aiding in a more informed and effective tuning process.
#
# Efficient Search and Filter: The use of a unique identifier for tagging facilitates an efficient and quick search for these specific runs among a multitude of others, enhancing the user experience in the MLflow UI.
#
# This approach, employing custom parameters and tagging, enhances the clarity and efficiency of the hyperparameter tuning process, contributing to building a more robust and optimized model.
#
# Let’s execute this section of the code and delve deeper into the insights and improvements it offers in the hyperparameter tuning process.

# %%
# Execute additional hyperparameter tuning runs with custom parameter choices
param_1_values = ["x", "y", "z"]
param_2_values = ["u", "v", "w"]
ident = "params_test_2"
consume(starmap(execute_tuning, ((x, param_1_values, param_2_values, ident) for x in range(5))))
# Out:
# 2024/08/12 16:01:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_0 at: http://localhost:5005/#/experiments/8/runs/2987b2ef50d342d5bc930c09652fb46a.
# 2024/08/12 16:01:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_0 at: http://localhost:5005/#/experiments/8/runs/b48649a4dfd544d2bbd5dc9d6d250295.
# 2024/08/12 16:01:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_0 at: http://localhost:5005/#/experiments/8/runs/3d05a4aaa65349d1a3763a38953a7c93.
# 2024/08/12 16:01:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_0 at: http://localhost:5005/#/experiments/8/runs/b2d535ab35004f9688c3d8fb22ae0561.
# 2024/08/12 16:01:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_0 at: http://localhost:5005/#/experiments/8/runs/0cd5ecfb76af4177ac5063896f874f1f.
# 2024/08/12 16:01:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_2_0 at: http://localhost:5005/#/experiments/8/runs/87cb229d1fa04bffa33ee08577261c5e.
# 2024/08/12 16:01:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_1 at: http://localhost:5005/#/experiments/8/runs/5d98a7db89d94206814ca2c940cfaa5a.
# 2024/08/12 16:01:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_1 at: http://localhost:5005/#/experiments/8/runs/c0676249874f491c977db8c71a351840.
# 2024/08/12 16:01:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_1 at: http://localhost:5005/#/experiments/8/runs/b62b00b335084166b15e67c100027cd0.
# 2024/08/12 16:01:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_1 at: http://localhost:5005/#/experiments/8/runs/924c4e79b9d84e209a8ba34cfaf1489a.
# 2024/08/12 16:01:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_1 at: http://localhost:5005/#/experiments/8/runs/7e91cc38ee3247759eb54d43a9f2b247.
# 2024/08/12 16:01:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_2_1 at: http://localhost:5005/#/experiments/8/runs/c781b78798664ed5a64c778856c47553.
# 2024/08/12 16:01:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_2 at: http://localhost:5005/#/experiments/8/runs/03aec982c6064855900c69e4c2404610.
# 2024/08/12 16:01:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:01:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_2 at: http://localhost:5005/#/experiments/8/runs/44a16d6c2c8f4e34b4824f9e628e443a.
# 2024/08/12 16:01:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_2 at: http://localhost:5005/#/experiments/8/runs/b79501db58d44369855a6e6d89ac25da.
# 2024/08/12 16:02:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_2 at: http://localhost:5005/#/experiments/8/runs/4afe5ffbb1f146d89d74ee02fb3ea394.
# 2024/08/12 16:02:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_2 at: http://localhost:5005/#/experiments/8/runs/316ff53c5f8c4247b6cfc4389583cc76.
# 2024/08/12 16:02:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_2_2 at: http://localhost:5005/#/experiments/8/runs/a4958482317c43439a50bf27d52e5bed.
# 2024/08/12 16:02:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_3 at: http://localhost:5005/#/experiments/8/runs/1b0549cd9e34491889b5367b0ef17a4c.
# 2024/08/12 16:02:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_3 at: http://localhost:5005/#/experiments/8/runs/3a5871cd02e74105b4ae7acfc6b9853c.
# 2024/08/12 16:02:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_3 at: http://localhost:5005/#/experiments/8/runs/221fc71143224e7cb9ebacf36fcee06a.
# 2024/08/12 16:02:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_3 at: http://localhost:5005/#/experiments/8/runs/4f2963daefe943a1ad8e40a176996d56.
# 2024/08/12 16:02:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_3 at: http://localhost:5005/#/experiments/8/runs/ac9eeb9440ab4cbeac120528daf054dc.
# 2024/08/12 16:02:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_2_3 at: http://localhost:5005/#/experiments/8/runs/52a9aa3aa3c74633afa7a8353549a7a7.
# 2024/08/12 16:02:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_4 at: http://localhost:5005/#/experiments/8/runs/cb0c74e59b554f019c143c35f9d6ffef.
# 2024/08/12 16:02:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/8/runs/ce4b3d035d4c4eb7a5a32a425f3ec9bc.
# 2024/08/12 16:02:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/8/runs/5dd232a2e5c6483c8ee664ad2478c640.
# 2024/08/12 16:02:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/8/runs/74de959e763d428f823cc2d00a957d4e.
# 2024/08/12 16:02:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/8/runs/8967cd8ed9804f15b2f655a95949baaf.
# 2024/08/12 16:02:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_2_4 at: http://localhost:5005/#/experiments/8/runs/68cede2baa464051a17a84ec696188eb.
# 2024/08/12 16:02:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.

# %% [markdown]
# # Refining the Hyperparameter Search Space
# In this phase, we focus on refining the hyperparameter search space. This is a crucial step in the hyperparameter tuning process. After a broad exploration of the parameter space, we are now narrowing down our search to a subset of parameter values.
#
# # What Are We Doing?
# Sub-setting Parameter Values: We are focusing on a more specific set of parameter values (param_1_values as ["b", "c"] and param_2_values as ["d", "f"]) based on insights gathered from previous runs.
#
# Tagging the Runs: Using a unique identifier (ident) for tagging ensures easy filtering and searching of these runs in the MLflow UI.
#
# # How Does It Apply to Hyperparameter Tuning?
# Focused Search: This narrowed search allows us to deeply explore the interactions and impacts of a specific set of parameter values, potentially leading to more optimized models.
#
# Efficient Resource Utilization: It enables more efficient use of computational resources by focusing the search on promising areas of the parameter space.
#
# # Caution
# While this approach is a common tactic in hyperparameter tuning, it’s crucial to acknowledge the implications. Comparing results from the narrowed search space directly with those from the original, broader search space can be misleading.
#
# # Why Is It Invalid to Compare?
# Nature of Bayesian Tuning Algorithms: Bayesian optimization and other tuning algorithms often depend on the exploration of a broad parameter space to make informed decisions. Restricting the parameter space can influence the behavior of these algorithms, leading to biased or suboptimal results.
#
# Interaction of Hyperparameter Selection Values: Different parameter values have different interactions and impacts on the model performance. A narrowed search space may miss out on capturing these interactions, leading to incomplete or skewed insights.
#
# In conclusion, while refining the search space is essential for efficient and effective hyperparameter tuning, it’s imperative to approach the comparison of results with caution,

# %%
param_1_values = ["b", "c"]
param_2_values = ["d", "f"]
ident = "params_test_3"
consume(starmap(execute_tuning, ((x, param_1_values, param_2_values, ident) for x in range(5))))
# Out:
# 2024/08/12 16:02:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_0 at: http://localhost:5005/#/experiments/8/runs/2039cc0633d44e588d189b5c53e59e40.
# 2024/08/12 16:02:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_0 at: http://localhost:5005/#/experiments/8/runs/c71edb51442147f7aafb96cb2eade74f.
# 2024/08/12 16:02:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_0 at: http://localhost:5005/#/experiments/8/runs/1e290aa56ab44bcfae4438f568f36dbc.
# 2024/08/12 16:02:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_0 at: http://localhost:5005/#/experiments/8/runs/a3e6e8a2ded540909aa0f48546115b75.
# 2024/08/12 16:02:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_0 at: http://localhost:5005/#/experiments/8/runs/cb89699a645d4c849f3985ad4fafcd4d.
# 2024/08/12 16:02:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_3_0 at: http://localhost:5005/#/experiments/8/runs/dc3d10b19c2949d89f099e207a040730.
# 2024/08/12 16:02:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_1 at: http://localhost:5005/#/experiments/8/runs/035364eb52df48478b521493cd588c81.
# 2024/08/12 16:02:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_1 at: http://localhost:5005/#/experiments/8/runs/bf55773fb8554e8d99ddd034caebcd57.
# 2024/08/12 16:02:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_1 at: http://localhost:5005/#/experiments/8/runs/02f3bba480ef4dcf9b2f7a04a47953a0.
# 2024/08/12 16:02:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:35 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_1 at: http://localhost:5005/#/experiments/8/runs/d1d36876f7a143f2ad85bcfaad1baf44.
# 2024/08/12 16:02:35 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_1 at: http://localhost:5005/#/experiments/8/runs/e698a963189941e9a21d3a297e3aa520.
# 2024/08/12 16:02:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_3_1 at: http://localhost:5005/#/experiments/8/runs/a5f7e0348b7045babdb08ea78a89d17a.
# 2024/08/12 16:02:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_2 at: http://localhost:5005/#/experiments/8/runs/5fa7ac2554b341d3993234356ad522ad.
# 2024/08/12 16:02:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_2 at: http://localhost:5005/#/experiments/8/runs/efc2d4afb4964d4ca3f06e013f4fd2aa.
# 2024/08/12 16:02:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_2 at: http://localhost:5005/#/experiments/8/runs/9d9208d440a8479bbf54548835de1aca.
# 2024/08/12 16:02:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_2 at: http://localhost:5005/#/experiments/8/runs/f46864afe37447be81cb8c1210abc675.
# 2024/08/12 16:02:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_2 at: http://localhost:5005/#/experiments/8/runs/62650338fb654432a94befa09361be1e.
# 2024/08/12 16:02:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_3_2 at: http://localhost:5005/#/experiments/8/runs/64d60f0f70cf4447a236de43a149d5ba.
# 2024/08/12 16:02:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_3 at: http://localhost:5005/#/experiments/8/runs/1f0792c64ec44e2891f6cd36ec419b86.
# 2024/08/12 16:02:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_3 at: http://localhost:5005/#/experiments/8/runs/a4266f33d1144c41bad21757e843a386.
# 2024/08/12 16:02:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_3 at: http://localhost:5005/#/experiments/8/runs/417ba96429dc4a1592df1ef55eeebf64.
# 2024/08/12 16:02:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_3 at: http://localhost:5005/#/experiments/8/runs/8b1dddc71a1c42b1935f1263502739ea.
# 2024/08/12 16:02:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_3 at: http://localhost:5005/#/experiments/8/runs/8343458505324479b17e84ab1545a60b.
# 2024/08/12 16:02:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_3_3 at: http://localhost:5005/#/experiments/8/runs/6d5f73fdf9e340cfbfee00cd6143f14e.
# 2024/08/12 16:02:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_4 at: http://localhost:5005/#/experiments/8/runs/d11a927f4b4d475586f52093687969d9.
# 2024/08/12 16:02:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/8/runs/2e465dbe98ab40b3be656cfd13aab225.
# 2024/08/12 16:02:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:02:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/8/runs/69441bca67874eb2a9e5b52179f9994c.
# 2024/08/12 16:02:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:03:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/8/runs/96e10c479c6140848292c6e94b78000c.
# 2024/08/12 16:03:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:03:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/8/runs/85f9e5bf14784be4b123c3e5580c51ad.
# 2024/08/12 16:03:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.
# 2024/08/12 16:03:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_params_test_3_4 at: http://localhost:5005/#/experiments/8/runs/3fc97e41183b489a85047f061ec51251.
# 2024/08/12 16:03:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/8.

# %% [markdown]
# # Challenge: Logging Best Metrics and Parameters
# In the real world of machine learning, it is crucial to keep track of the best performing models and their corresponding parameters for easy comparison and reproduction. Your challenge is to enhance the ``execute_tuning`` function to log the best metrics and parameters from the child runs in each parent run. This way, you can easily compare the best-performing models across different parent runs within the MLflow UI.
#
# # Your Task:
# Modify the execute_tuning function such that for each parent run, it logs the best (minimum) metric1 found among all its child runs.
#
# Alongside the best metric1, also log the parameters param1 and param2 that yielded this best metric1.
#
# Ensure that the execute_tuning function can accept a num_child_runs parameter to specify how many child iterations to perform per parent run.
#
# This is a common practice that allows you to keep your MLflow experiments organized and easily retrievable, making the model selection process smoother and more efficient.
#
# Hint: You might want to return values from the log_run function and use these returned values in the execute_tuning function to keep track of the best metrics and parameters.
#
# # Note:
# Before moving on to the solution below, give it a try yourself! This exercise is a great opportunity to familiarize yourself with advanced features of MLflow and improve your MLOps skills. If you get stuck or want to compare your solution, you can scroll down to see a possible implementation.

# %%
# Define a function to log parameters and metrics and add tag
# logging for search_runs functionality
def log_run(run_name, test_no, param1_choices, param2_choices, tag_ident):
    with mlflow.start_run(run_name=run_name, nested=True) as run:
        param1 = random.choice(param1_choices)
        param2 = random.choice(param2_choices)
        metric1 = random.uniform(0, 1)
        metric2 = abs(random.gauss(5, 2.5))

        mlflow.log_param("param1", param1)
        mlflow.log_param("param2", param2)
        mlflow.log_metric("metric1", metric1)
        mlflow.log_metric("metric2", metric2)
        mlflow.set_tag("test_identifier", tag_ident)

        return run.info.run_id, metric1, param1, param2


# Generate run names
def generate_run_names(test_no, num_runs=5):
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function, allowing for param overrides,
# run_name disambiguation, and tagging support
def execute_tuning(
    test_no,
    param1_choices=("a", "b", "c"),
    param2_choices=("d", "e", "f"),
    test_identifier="",
    num_child_runs=5,
):
    ident = "default" if not test_identifier else test_identifier
    best_metric1 = float("inf")
    best_params = None
    # Use a parent run to encapsulate the child runs
    with mlflow.start_run(run_name=f"parent_run_test_{ident}_{test_no}"):
        # Partial application of the log_run function
        log_current_run = partial(
            log_run,
            test_no=test_no,
            param1_choices=param1_choices,
            param2_choices=param2_choices,
            tag_ident=ident,
        )
        mlflow.set_tag("test_identifier", ident)
        # Generate run names and apply log_current_run function to each run name
        results = list(
            starmap(
                log_current_run,
                ((run_name,) for run_name in generate_run_names(test_no, num_child_runs)),
            )
        )

        for _, metric1, param1, param2 in results:
            if metric1 < best_metric1:
                best_metric1 = metric1
                best_params = (param1, param2)

        mlflow.log_metric("best_metric1", best_metric1)
        mlflow.log_param("best_param1", best_params[0])
        mlflow.log_param("best_param2", best_params[1])
        # Consume the iterator to execute the runs
        consume(results)



param_1_values = ["a", "b"]
param_2_values = ["d", "f"]

# Execute hyperparameter tuning runs with custom parameter choices
consume(
    starmap(
        execute_tuning, ((x, param_1_values, param_2_values, "subset_test", 25) for x in range(5))
    )
)
# Out:
# 2024/08/12 16:03:02 INFO mlflow.tracking.fluent: Experiment with name 'Parent Child Association Challenge' does not exist. Creating a new experiment.
# 2024/08/12 16:03:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_0 at: http://localhost:5005/#/experiments/9/runs/e8ad57b7f2124959913e01a689527a56.
# 2024/08/12 16:03:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:03:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_0 at: http://localhost:5005/#/experiments/9/runs/ef69b0bb520643e08c35de00d1f1e23b.
# 2024/08/12 16:03:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:03:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_0 at: http://localhost:5005/#/experiments/9/runs/19d93fc4adbd4ccfaef8075e11c8723b.
# 2024/08/12 16:03:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:03:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run run
INFO mlflow.tracking._tracking_service.client: 🏃 View run run_20_test_1 at: http://localhost:5005/#/experiments/9/runs/d64221fc77d64ae79d0537f04a191b37.
# 2024/08/12 16:04:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_21_test_1 at: http://localhost:5005/#/experiments/9/runs/4b8affd8eecb4c608222226e220a9f57.
# 2024/08/12 16:04:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_22_test_1 at: http://localhost:5005/#/experiments/9/runs/8f1865a6f8ef4d61ab7890abfb13cc0c.
# 2024/08/12 16:04:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_23_test_1 at: http://localhost:5005/#/experiments/9/runs/762b5f06803e4b03bcbc892d4263a950.
# 2024/08/12 16:04:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_24_test_1 at: http://localhost:5005/#/experiments/9/runs/bffb049edfae4956ab94614cbb286dfd.
# 2024/08/12 16:04:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_subset_test_1 at: http://localhost:5005/#/experiments/9/runs/c64269e673e1474c81e078995027f9c9.
# 2024/08/12 16:04:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_2 at: http://localhost:5005/#/experiments/9/runs/07e239b5787c481395c64707c1f58efc.
# 2024/08/12 16:04:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_2 at: http://localhost:5005/#/experiments/9/runs/bafe91b27a3c41aa8c84384c030a3042.
# 2024/08/12 16:04:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_2 at: http://localhost:5005/#/experiments/9/runs/d02f61e00e5e4708b2704fe8b7bb277c.
# 2024/08/12 16:04:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_2 at: http://localhost:5005/#/experiments/9/runs/9c3323f0788248b89b5bfb78282dd140.
# 2024/08/12 16:04:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_2 at: http://localhost:5005/#/experiments/9/runs/0ae4ac413b184b669956de94a835e136.
# 2024/08/12 16:04:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_5_test_2 at: http://localhost:5005/#/experiments/9/runs/ac135884eecc42fdbcd165c0f798277c.
# 2024/08/12 16:04:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_6_test_2 at: http://localhost:5005/#/experiments/9/runs/2eb397f75a834f08b3f77a62363de46e.
# 2024/08/12 16:04:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_7_test_2 at: http://localhost:5005/#/experiments/9/runs/94dcd96822594572b2e4f87c527ed02c.
# 2024/08/12 16:04:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_8_test_2 at: http://localhost:5005/#/experiments/9/runs/9adb079bb4f84106b3f7257d529a0b55.
# 2024/08/12 16:04:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_9_test_2 at: http://localhost:5005/#/experiments/9/runs/5cfdaac143e74d469f787cfeb6d5bca4.
# 2024/08/12 16:04:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_10_test_2 at: http://localhost:5005/#/experiments/9/runs/83e199aff13e470282947bf245e8b595.
# 2024/08/12 16:04:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_11_test_2 at: http://localhost:5005/#/experiments/9/runs/6cc4fe82a2b04718b1f1cf4ba5471ee3.
# 2024/08/12 16:04:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_12_test_2 at: http://localhost:5005/#/experiments/9/runs/196bd396a6a34c01915ab0e05ba0e3fc.
# 2024/08/12 16:04:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_13_test_2 at: http://localhost:5005/#/experiments/9/runs/b2dc982d99f247b29eb62de8db9a5dd6.
# 2024/08/12 16:04:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_14_test_2 at: http://localhost:5005/#/experiments/9/runs/72c66633f1a047f9b9f7d9aef24f3316.
# 2024/08/12 16:04:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:04:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run run
INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_11_test_3 at: http://localhost:5005/#/experiments/9/runs/56845a65b81644369635f846a36e06af.
# 2024/08/12 16:05:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_12_test_3 at: http://localhost:5005/#/experiments/9/runs/0dbe9e66d15b4db884fc98da1f912b1a.
# 2024/08/12 16:05:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_13_test_3 at: http://localhost:5005/#/experiments/9/runs/768c217e6f5e4ce39a336a3fc30fde05.
# 2024/08/12 16:05:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:26 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_14_test_3 at: http://localhost:5005/#/experiments/9/runs/657784539c8b4ca08fdade9bff1fd645.
# 2024/08/12 16:05:26 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_15_test_3 at: http://localhost:5005/#/experiments/9/runs/6326bcaff21c4bebb258806edcf263aa.
# 2024/08/12 16:05:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_16_test_3 at: http://localhost:5005/#/experiments/9/runs/c47baf34b1444b3ca04f22a2aba9fc8f.
# 2024/08/12 16:05:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_17_test_3 at: http://localhost:5005/#/experiments/9/runs/04f0dd02320c4743a4e88de58dfa7b40.
# 2024/08/12 16:05:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_18_test_3 at: http://localhost:5005/#/experiments/9/runs/e454437190e548b28e524f35f00dbcc0.
# 2024/08/12 16:05:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_19_test_3 at: http://localhost:5005/#/experiments/9/runs/2a8bbdb62b5d4e319082166888caaafd.
# 2024/08/12 16:05:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_20_test_3 at: http://localhost:5005/#/experiments/9/runs/346c6084225047fe94be3629ee407d95.
# 2024/08/12 16:05:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:37 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_21_test_3 at: http://localhost:5005/#/experiments/9/runs/4f41419a34504dfebb3556f3266d40c3.
# 2024/08/12 16:05:37 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_22_test_3 at: http://localhost:5005/#/experiments/9/runs/ba3198856fc246eb88a7a64b5a0f918e.
# 2024/08/12 16:05:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_23_test_3 at: http://localhost:5005/#/experiments/9/runs/eb5235bf7bfc4286a04572f04e9b984b.
# 2024/08/12 16:05:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_24_test_3 at: http://localhost:5005/#/experiments/9/runs/7f14fce9d5ab45aeab982608b3700955.
# 2024/08/12 16:05:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_subset_test_3 at: http://localhost:5005/#/experiments/9/runs/7a31de79339d40d38551e3fbfdf925ed.
# 2024/08/12 16:05:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_0_test_4 at: http://localhost:5005/#/experiments/9/runs/da0a381d7f0c486b9f29e09cf9c1cdb2.
# 2024/08/12 16:05:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:47 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_1_test_4 at: http://localhost:5005/#/experiments/9/runs/d3b09e9758064a5a9dc967859167d5a3.
# 2024/08/12 16:05:47 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_2_test_4 at: http://localhost:5005/#/experiments/9/runs/49bd07b4b6e9417399da2bdc2d9542a7.
# 2024/08/12 16:05:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_3_test_4 at: http://localhost:5005/#/experiments/9/runs/52533acdc0614968a5de02b26131e49b.
# 2024/08/12 16:05:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:51 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_4_test_4 at: http://localhost:5005/#/experiments/9/runs/2b19c09eedf343cbb2ba1877f25c3eb9.
# 2024/08/12 16:05:51 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_5_test_4 at: http://localhost:5005/#/experiments/9/runs/9293979e9b5849809be3db0995598bc6.
# 2024/08/12 16:05:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_6_test_4 at: http://localhost:5005/#/experiments/9/runs/f472866dd73a4a1698ac13ead0cfb4d2.
# 2024/08/12 16:05:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_7_test_4 at: http://localhost:5005/#/experiments/9/runs/1f36439f051e4374836b585f20e2b8e1.
# 2024/08/12 16:05:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_8_test_4 at: http://localhost:5005/#/experiments/9/runs/d3ddbef041c948e5b60f04c79a22c97e.
# 2024/08/12 16:05:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:05:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_9_test_4 at: http://localhost:5005/#/experiments/9/runs/e3336a1c813840729508ff56e05e170c.
# 2024/08/12 16:05:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_10_test_4 at: http://localhost:5005/#/experiments/9/runs/78696632c8c346808a7aa46fe439d9ae.
# 2024/08/12 16:06:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_11_test_4 at: http://localhost:5005/#/experiments/9/runs/bb61f7b91690436bb5f58af689701913.
# 2024/08/12 16:06:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:04 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_12_test_4 at: http://localhost:5005/#/experiments/9/runs/36f32300727e4b00ad36e4585ea135c5.
# 2024/08/12 16:06:04 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_13_test_4 at: http://localhost:5005/#/experiments/9/runs/ff9c4083006c4fdc88e3fbbd580345e2.
# 2024/08/12 16:06:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_14_test_4 at: http://localhost:5005/#/experiments/9/runs/9983dd4431b446669c43a8d07ef34eba.
# 2024/08/12 16:06:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:09 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_15_test_4 at: http://localhost:5005/#/experiments/9/runs/51bb3bbe487c4c18a99d3e96b16d724b.
# 2024/08/12 16:06:09 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_16_test_4 at: http://localhost:5005/#/experiments/9/runs/65ef6f6098ff4e198edf6f85f18a90fc.
# 2024/08/12 16:06:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:12 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_17_test_4 at: http://localhost:5005/#/experiments/9/runs/656ef2adff064e62919aa0516e62da93.
# 2024/08/12 16:06:12 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_18_test_4 at: http://localhost:5005/#/experiments/9/runs/fecf569e14bf4655b59917176dc63ed4.
# 2024/08/12 16:06:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_19_test_4 at: http://localhost:5005/#/experiments/9/runs/1b09b03d73904c3d964bb4026e5f3b84.
# 2024/08/12 16:06:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_20_test_4 at: http://localhost:5005/#/experiments/9/runs/6a8e3baeb6354e37a5752ad869a19518.
# 2024/08/12 16:06:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_21_test_4 at: http://localhost:5005/#/experiments/9/runs/ec429eb312cb4ad8929c1fb715497960.
# 2024/08/12 16:06:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:20 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_22_test_4 at: http://localhost:5005/#/experiments/9/runs/7d536512e0b84781a1e60e21de45a205.
# 2024/08/12 16:06:20 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_23_test_4 at: http://localhost:5005/#/experiments/9/runs/65fbc99783814ac7bc192221dcc9724e.
# 2024/08/12 16:06:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run run_24_test_4 at: http://localhost:5005/#/experiments/9/runs/4168ddbaad934c368538d90ed791126d.
# 2024/08/12 16:06:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
# 2024/08/12 16:06:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run parent_run_test_subset_test_4 at: http://localhost:5005/#/experiments/9/runs/6f7ebd4a36ab4447ada779620a4b98c4.
# 2024/08/12 16:06:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5005/#/experiments/9.
